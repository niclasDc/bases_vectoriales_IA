# %%
#* Librerías importantes
import chromadb

# %%
client = chromadb.Client() #* Crea instancia de chroma para manejar la comunicación con la base de datos
print("Chroma Inicializado correctamente")
# Out:
# Chroma Inicializado correctamente

# %%
#* Chroma_bd - Maneja colecciones que son tablas en la base de datos

test_collection = client.get_or_create_collection(name="test_collection")

# %%
print(f"Colección creada o recuperada correctamente: {test_collection.name}")
# Out:
# Colección creada o recuperada correctamente: test_collection
